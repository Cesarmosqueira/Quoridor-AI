# %% [markdown]
# <h1>Algoritmo Dijktra</h1><br>
# <b><i>El algoritmo de Dijkstra permite hallar caminos más cortos entre un par de nodos de un grafo.</i></b><br><br>
# Como explicamos en el <a href="Trabajo_Parcial_Complejidad.ipynb">informe principal</a>, este algoritmo nos permitirá hallar el camino más corto entre dos puntos en el tablero, tratando a este como una <code>matriz de adyacencia</code>. <br> <p>En este caso demostraremos la utilidad de Dijkstra en nuestro juego, hallando la distancia más corta entre 2 puntos del grafo.</p>

# %%
n = int(input())
edges = []

for i in range(n):
    edges.append([int(x) for x in input().split()])
# Out:
# 8
# 0 1 40
# 0 3 50
# 0 4 20
# 1 3 4
# 3 4 15
# 1 2 10
# 2 5 5
# 3 5 80

# %%
start, end = [int(x) for x in input("Start and end ").split()]      

def to_adj(edges, size):
    vs = [[] for _ in range(size)]
    for src, dst, w in edges:
        vs[src].append([dst, w]) ##undirected
        vs[dst].append([src, w])
    return vs

def dijkstra(vs, start, end):
    cost = [float('inf')]*len(vs)
    parents = [-1]*len(vs)
    cost[start] = 0
    for i in range(len(vs)):
        for e, w in vs[i]:
            if parents[e] == -1:
                parents[e] = i
            new_cost = cost[i]+w
            if cost[e] > new_cost:
                cost[e] = new_cost
                parents[e] = i
    return cost[end]

adj = to_adj(edges, n)
print(f"Costo minimo de {start} a {end} = ", dijkstra(adj, start, end))
# Out:
# Start and end 0 5
# Costo minimo de 0 a 5 =  55

# %% [markdown]
# ![image.png](attachment:image.png)
